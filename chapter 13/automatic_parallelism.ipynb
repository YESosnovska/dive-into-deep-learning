# %%
import torch
from d2l import torch as d2l

# %%
devices = d2l.try_all_gpus()
def run(x):
    return [x.mm(x) for _ in range(50)]

x_gpu1 = torch.rand(size=(4000, 4000), device=devices[0])
x_gpu2 = torch.rand(size=(4000, 4000), device=devices[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 6
#       3     return [x.mm(x) for _ in range(50)]
#       5 x_gpu1 = torch.rand(size=(4000, 4000), device=devices[0])
# ----> 6 x_gpu2 = torch.rand(size=(4000, 4000), device=devices[1])
#
# IndexError: list index out of range

# %%
run(x_gpu1)
run(x_gpu2)  # Warm-up all devices
torch.cuda.synchronize(devices[0])
torch.cuda.synchronize(devices[1])

with d2l.Benchmark('GPU1 time'):
    run(x_gpu1)
    torch.cuda.synchronize(devices[0])

with d2l.Benchmark('GPU2 time'):
    run(x_gpu2)
    torch.cuda.synchronize(devices[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 run(x_gpu1)
# ----> 2 run(x_gpu2)  # Warm-up all devices
#       3 torch.cuda.synchronize(devices[0])
#       4 torch.cuda.synchronize(devices[1])
#
# NameError: name 'x_gpu2' is not defined

# %%
with d2l.Benchmark('GPU1 & GPU2'):
    run(x_gpu1)
    run(x_gpu2)
    torch.cuda.synchronize()
# Out:
# GPU1 & GPU2: 0.0021 sec
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 with d2l.Benchmark('GPU1 & GPU2'):
#       2     run(x_gpu1)
# ----> 3     run(x_gpu2)
#       4     torch.cuda.synchronize()
#
# NameError: name 'x_gpu2' is not defined

# %%
def copy_to_cpu(x, non_blocking=False):
    return [y.to('cpu', non_blocking=non_blocking) for y in x]

with d2l.Benchmark('Run on GPU1'):
    y = run(x_gpu1)
    torch.cuda.synchronize()

with d2l.Benchmark('Copy to CPU'):
    y_cpu = copy_to_cpu(y)
    torch.cuda.synchronize()
# Out:
# Run on GPU1: 1.8491 sec
# Copy to CPU: 0.8973 sec

# %%
with d2l.Benchmark('Run on GPU1 and copy to CPU'):
    y = run(x_gpu1)
    y_cpu = copy_to_cpu(y, True)
    torch.cuda.synchronize()
# Out:
# Run on GPU1 and copy to CPU: 6.7035 sec
