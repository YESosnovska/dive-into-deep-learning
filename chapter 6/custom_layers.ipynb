# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l

# %%
class CenteredLayer(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, X):
        return X - X.mean()

# %%
layer = CenteredLayer()
layer(torch.tensor([1.0, 2, 3, 4, 5]))
# Out:
# tensor([-2., -1.,  0.,  1.,  2.])

# %%
net = nn.Sequential(nn.LazyLinear(128), CenteredLayer())

# %%
Y = net(torch.rand(4, 8))
Y.mean()
# Out:
# tensor(3.9581e-09, grad_fn=<MeanBackward0>)

# %%
class MyLinear(nn.Module):
    def __init__(self, in_units, units):
        super().__init__()
        self.weight = nn.Parameter(torch.randn(in_units, units))
        self.bias = nn.Parameter(torch.randn(units,))

    def forward(self, X):
        linear = torch.matmul(X, self.weight.data) + self.bias.data
        return F.relu(linear)

# %%
linear = MyLinear(5, 3)
linear.weight
# Out:
# Parameter containing:
# tensor([[-2.1635, -1.5941, -0.8813],
#         [-0.5243, -0.9982,  1.1363],
#         [ 0.4518,  0.2023,  0.8433],
#         [ 0.6980,  0.8335,  0.2520],
#         [-0.0761,  0.0216, -0.0731]], requires_grad=True)

# %%
linear(torch.rand(2, 5))
# Out:
# tensor([[0.0000, 0.8474, 2.6333],
#         [0.0000, 0.9024, 1.2305]])

# %%
net = nn.Sequential(MyLinear(64, 8), MyLinear(8, 1))
net(torch.rand(2, 64))
# Out:
# tensor([[0.],
#         [0.]])
